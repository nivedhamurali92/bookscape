# %%
# !pip install requests pandas

import requests
import pandas as pd
import requests

# %%
key = "AIzaSyCr4DuoWPS_IKBDfo8W5dC3W68l4kp1ZeY"
link = "https://www.googleapis.com/books/v1/volumes"

# %%
def fetch_books(query, max_results=500):
        books = []
        start_index = 0
        results_per_request = 40  # Maximum results per API request

        while len(books) < max_results:
            params = {
                "q": query,
                "startIndex": start_index,
                "maxResults": min(results_per_request, max_results - len(books)),
                "key": "AIzaSyCr4DuoWPS_IKBDfo8W5dC3W68l4kp1ZeY"#your api key
            }

            response = requests.get("https://www.googleapis.com/books/v1/volumes", params=params)
            if response:
                data = response.json()
                items = data.get("items", [])
                books.extend(items)

                if len(items) < results_per_request:
                    break  # No more results to fetch
                start_index += results_per_request
            else:
                print(f"Error: {response.status_code} - {response.text}")
                break



        return books

# %%
def books_data(data):
      books = []
      for book in data:
              volume_info = book.get("volumeInfo", {})
              sale_info = book.get("saleInfo", {})

              # Extract book details
              my_dic = dict(book_id = book.get("id"),
              title = volume_info.get("title", "Unknown"),
              subtitle = volume_info.get("subtitle", ""),
              authors = ", ".join(volume_info.get("authors", [])),
              publisher = volume_info.get("publisher", ""),
              description = volume_info.get("description", ""),
              industry_identifiers = str(volume_info.get("industryIdentifiers", [])),
              text_mode = volume_info.get("readingModes", {}).get("text", False),
              image_mode = volume_info.get("readingModes", {}).get("image", False),
              page_count = volume_info.get("pageCount", 0),
              categories = ", ".join(volume_info.get("categories", [])),
              language = volume_info.get("language", "Unknown"),
              image_links = str(volume_info.get("imageLinks", {})),
              ratings_count = volume_info.get("ratingsCount", 0),
              average_rating = volume_info.get("averageRating", 0),
              country = sale_info.get("country", "Unknown"),
              saleability = sale_info.get("saleability", "Unknown"),
              is_ebook = sale_info.get("isEbook", False),
              list_price = sale_info.get("listPrice", {}).get("amount", 0),
              list_price_currency = sale_info.get("listPrice", {}).get("currencyCode", ""),
              retail_price = sale_info.get("retailPrice", {}).get("amount", 0),
              retail_price_currency = sale_info.get("retailPrice", {}).get("currencyCode", ""),
              buy_link = sale_info.get("buyLink", ""),
              published_year = volume_info.get("publishedDate", "Unknown"))
              
            

              books.append(my_dic)
      return pd.DataFrame(books)

# %%
py_book = books_data(fetch_books('Python', max_results=500))
sql_books = books_data(fetch_books('sql', max_results=500))
data_sci = books_data(fetch_books('data science', max_results=500))

# %%
final_df = pd.concat([py_book,sql_books,data_sci])
len(final_df)
# Out:
# 1500

# %%
pd.set_option('display.max_columns',None)

# %%
final_df
# Out:
#           book_id                                              title  \
# 0    v1jvDwAAQBAJ                     LEARN PYTHON WITH 200 PROGRAMS
# 1    bIZHCgAAQBAJ                                      Fluent Python
# 2    KZvM0AEACAAJ                                   Effective Python
# 3    igYvDwAAQBAJ                                Python Crash Course
# 4    S_SJ2LaZH8EC                                    Python Cookbook
# ..            ...                                                ...
# 495  FPFRAAAAMAAJ  Wave Optics and Photonic Devices for Optical I...
# 496  bQIKAQAAMAAJ     Scientific Basis of Noise-induced Hearing Loss
# 497  jgsbAQAAMAAJ  Bibliography of Scientific and Industrial Reports
# 498  2Iw-AQAAIAAJ                                             Signal
# 499  6TRmAAAAMAAJ                              Dating in Archaeology
#
#                                               subtitle  \
# 0          PRACTICAL GUIDE FOR CBSE XI,XII & BEGINEERS
# ...

# %%
final_df.dtypes
# Out:
# book_id                   object
# title                     object
# subtitle                  object
# authors                   object
# publisher                 object
# description               object
# industry_identifiers      object
# text_mode                   bool
# image_mode                  bool
# page_count                 int64
# categories                object
# language                  object
# image_links               object
# ratings_count              int64
# average_rating           float64
# country                   object
# saleability               object
# is_ebook                    bool
# list_price               float64
# list_price_currency       object
# retail_price             float64
# retail_price_currency     object
# buy_link                  object
# published_year            object
# dtype: object

# %%
final_df['published_year'] = pd.to_datetime(final_df['published_year'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 final_df['published_year'] = pd.to_datetime(final_df['published_year'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
# Attempt to convert the column to datetime
final_df['published_year'] = pd.to_datetime(final_df['published_year'], errors='coerce')

# Display the result
print(final_df)
# Out:
#           book_id                                              title  \
# 0    v1jvDwAAQBAJ                     LEARN PYTHON WITH 200 PROGRAMS
# 1    bIZHCgAAQBAJ                                      Fluent Python
# 2    KZvM0AEACAAJ                                   Effective Python
# 3    igYvDwAAQBAJ                                Python Crash Course
# 4    S_SJ2LaZH8EC                                    Python Cookbook
# ..            ...                                                ...
# 495  FPFRAAAAMAAJ  Wave Optics and Photonic Devices for Optical I...
# 496  bQIKAQAAMAAJ     Scientific Basis of Noise-induced Hearing Loss
# 497  jgsbAQAAMAAJ  Bibliography of Scientific and Industrial Reports
# 498  2Iw-AQAAIAAJ                                             Signal
# 499  6TRmAAAAMAAJ                              Dating in Archaeology
#
#                                               subtitle  \
# 0          PRACTICAL GUIDE FOR CBSE XI,XII & BEGINEERS
# ...

# %%
final_df.fillna('', inplace=True)

# %%
final_df
# Out:
#           book_id                                              title  \
# 0    v1jvDwAAQBAJ                     LEARN PYTHON WITH 200 PROGRAMS
# 1    bIZHCgAAQBAJ                                      Fluent Python
# 2    KZvM0AEACAAJ                                   Effective Python
# 3    igYvDwAAQBAJ                                Python Crash Course
# 4    S_SJ2LaZH8EC                                    Python Cookbook
# ..            ...                                                ...
# 495  FPFRAAAAMAAJ  Wave Optics and Photonic Devices for Optical I...
# 496  bQIKAQAAMAAJ     Scientific Basis of Noise-induced Hearing Loss
# 497  jgsbAQAAMAAJ  Bibliography of Scientific and Industrial Reports
# 498  2Iw-AQAAIAAJ                                             Signal
# 499  6TRmAAAAMAAJ                              Dating in Archaeology
#
#                                               subtitle  \
# 0          PRACTICAL GUIDE FOR CBSE XI,XII & BEGINEERS
# ...

# %%
import pymysql

# %%
db_config ={
    'host':'localhost',
     'user':'root',
      'password':'kasthuri67' 
}

conn = pymysql.connect(**db_config)
cursor=conn.cursor()
cursor.execute("create database if not exists books")
cursor.execute("use books")
# Out:
# 0

# %%
create_table_query = """
CREATE TABLE IF NOT EXISTS book_ (
    book_id VARCHAR(255),                         
    title VARCHAR(255),
    subtitle TEXT,                        
    authors  TEXT,
    publisher VARCHAR(255),
    description TEXT,                   
    industry_identifiers TEXT,            
    text_mode  BOOLEAN,                      
    image_mode BOOLEAN,                       
    page_count INT,                       
    categories TEXT,                      
    language VARCHAR(10),                       
    image_links TEXT,                   
    ratings_count INT,                    
    average_rating DECIMAL(10, 2) NULL,                
    country VARCHAR(100),                          
    saleability VARCHAR(50),                      
    is_ebook BOOLEAN,                         
    list_price DECIMAL(10,2),                     
    list_price_currency VARCHAR(50),             
    retail_price DECIMAL(10,2),                
    retail_price_currency VARCHAR(50),           
    buy_link TEXT,                         
    published_year DATE
)
"""
cursor.execute(create_table_query)
print("Table `book_tables1` created or already exists.")
# Out:
# Table `book_tables1` created or already exists.

# %%
insert_query = """
INSERT INTO book_tables1 (
    book_id,                         
    title,                            
    subtitle,                         
    authors,
    publisher,
    description,                      
    industry_identifiers,             
    text_mode,                         
    image_mode,                        
    page_count,                        
    categories,                       
    language,                        
    image_links,                      
    ratings_count,                     
    average_rating,                  
    country,                          
    saleability,                      
    is_ebook,                          
    list_price,                      
    list_price_currency,            
    retail_price,                   
    retail_price_currency,               
    buy_link,                        
    published_year
) 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
for index, row in final_df.iterrows():
    cursor.execute(insert_query, (row['book_id'], row['title'], row['subtitle'], row['authors'], row['publisher'], row['description'], row['industry_identifiers'], row['text_mode'], row['image_mode'], row['page_count'], row['categories'], row['language'], row['image_links'], row['ratings_count'], row['average_rating'], row['country'], row['saleability'], row['is_ebook'], row['list_price'], row['list_price_currency'], row['retail_price'], row['retail_price_currency'], row['buy_link'], row['published_year']))
    
conn.commit()

# %%
final_df=final_df.fillna(0)

# %%
if published_year == '':
    published_year = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 if published_year == '':
#       2     published_year = None
#
# NameError: name 'published_year' is not defined

# %%
final_df['published_year'] = final_df['published_year'].replace('', None)

# %%
final_df['publisher'] = final_df['publisher'].replace({pd.NA: None, '': None})

# %%
final_df['publisher']
# Out:
# 0                                          Notion Press
# 1                                 "O'Reilly Media, Inc."
# 2                                                   None
# 3                                        No Starch Press
# 4                                 "O'Reilly Media, Inc."
#                              ...
# 495    SPIE-International Society for Optical Enginee...
# 496                                                 None
# 497                                                 None
# 498                                                 None
# 499                                     J.M. Dent & Sons
# Name: publisher, Length: 1500, dtype: object

# %%
final_df.dtypes
# Out:
# book_id                          object
# title                            object
# subtitle                         object
# authors                          object
# publisher                        object
# description                      object
# industry_identifiers             object
# text_mode                          bool
# image_mode                         bool
# page_count                        int64
# categories                       object
# language                         object
# image_links                      object
# ratings_count                     int64
# average_rating                  float64
# country                          object
# saleability                      object
# is_ebook                           bool
# list_price                      float64
# list_price_currency              object
# retail_price                    float64
# retail_price_currency            object
# buy_link                         object
# ...

# %%
final_df['publisher']=final_df['publisher'].astype(str)
