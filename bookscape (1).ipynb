# %%
import pandas as pd

# %%
import requests

# %%
link = "https://www.googleapis.com/books/v1/volumes"
api_key = "AIzaSyCr4DuoWPS_IKBDfo8W5dC3W68l4kp1ZeY"

# %%
input=input()
# Out:
#  python

# %%
def fetch_books(query, api_key, max_results=10):
    books = []  
    url = "https://www.googleapis.com/books/v1/volumes"
    start_index = 0
    max_per_request = 40
    while start_index < max_results:
       
        params = {
            "q": query,
            "key": api_key,
            "startIndex": start_index,
            "maxResults": min(max_per_request, max_results - start_index),
        }
  # Make API request
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"Error: {response.status_code} - {response.text}")
            break
        data = response.json()
        items = data.get("items", [])
        if not items:
            print("No more data to fetch.")
            break
        for item in items:
            volume_info = item.get("volumeInfo", {})
            sale_info = item.get("saleInfo", {})
            books.append({
                "book_id": item.get("id", ""),
                "search_key": query,
                "book_title": volume_info.get("title", ""),
                "book_subtitle": volume_info.get("subtitle", "NA"),
                "book_authors": ", ".join(volume_info.get("authors", [])),
                "book_publisher": volume_info.get("publisher", ""),                
                "industryIdentifiers": volume_info.get("industryIdentifiers", [{}])[0].get("type", ""),
                "text_readingModes": volume_info.get("readingModes", {}).get("text", False),
                "image_readingModes": volume_info.get("readingModes", {}).get("image", False),
                "categories": ", ".join(volume_info.get("categories", [])),
                "published_year": volume_info.get("publishedDate", "")[:4] if volume_info.get("publishedDate", "") else "",
                "saleability": sale_info.get("saleability", ""),
                "list_price": sale_info.get("listPrice", {}).get("amount", 0.0),
                "currencyCode_listPrice": sale_info.get("listPrice", {}).get("currencyCode", ""),
                "retail_price": sale_info.get("retailPrice", {}).get("amount", 0.0),
                "currencyCode_retailPrice": sale_info.get("retailPrice", {}).get("currencyCode", ""),
                "average_rating": volume_info.get("averageRating", 0.0),
                "ratings_count": volume_info.get("ratingsCount", 0),
                "country": volume_info.get("country", ""),
                "page_count": volume_info.get("pageCount", 0),
                "language": volume_info.get("language", ""),                
                "is_ebook": sale_info.get("isEbook", False),                
            })

        # Increment start index for pagination
        start_index += max_per_request

    return books

# %%
"""queries = [
    "html",
    "javascript",
    "statics",
    "artificial intelligence",
    "sql"
]
books_data = []
for query in queries:
        print(f"Fetching books for query: {query}")
        all_books = fetch_books(query, api_key)
        books_data.extend(all_books)
"""
books_data = fetch_books('civics', api_key)

# %%
books_df = pd.DataFrame(books_data)
books_df
# Out:
#         book_id search_key                                         book_title  \
# 0  CxJn0AEACAAJ     civics                      Social and Political Life-III
# 1  EXUWEAAAQBAJ     civics               Excursions 8 History/Civics- (17-18)
# 2  MHM-EAAAQBAJ     civics  Solutions to FOCUS ON History and CIVICS for C...
# 3  oJyPxgEACAAJ     civics                                             French
# 4  JwFjDwAAQBAJ     civics           New Transitions  History and Civics  6
# 5  X9ExEAAAQBAJ     civics                      My Book of History & Civics 8
# 6  mQwOx8KWzk8C     civics                                    Civic Education
# 7  wyoxDAAAQBAJ     civics               Transitions  History and Civics  8
# 8  lS4XAAAAIAAJ     civics                                     The New Civics
# 9  J1oXEQAAQBAJ     civics  An Introduction to Civics and Citizenship Educ...
#
#                                        book_subtitle  \
# 0                           Textbook for Class VIII.
# 1                                                 NA
# 2                                                 NA
# 3  Teachers and Students Wide Ruled Line Journal ...
# 4                                                 NA
# 5                                                 NA
# 6                          What Makes Students Learn
# 7                                                 NA
# 8                   A Textbook for Secondary Schools
# 9            A Machine-Generated Literature Overview
#
#                                         book_authors  \
# 0
# 1                                          No Author
# 2  I. L. Wanchoo, Arun Kumar, Goyal Brothers Prak...
# 3                              Olivia Julius Dunggat
# 4                     Anuradha Sud, Shiladitya Ghosh
# 5                                     Manju Bhashini
# 6                        Richard G. Niemi, Jane Junn
# 7                                   Shiladitya Ghosh
# 8                                Roscoe Lewis Ashley
# 9                                      Keith Heggart
#
#              book_publisher industryIdentifiers  text_readingModes  \
# 0                                         OTHER              False
# 1             HarperCollins             ISBN_13              False
# 2  Goyal Brothers Prakashan                                  False
# 3   Independently Published             ISBN_10              False
# 4    Vikas Publishing House             ISBN_13              False
# 5   Saraswati House Pvt Ltd             ISBN_13              False
# 6     Yale University Press             ISBN_10               True
# 7    Vikas Publishing House             ISBN_13              False
# 8                                         OTHER              False
# 9           Springer Nature             ISBN_13               True
#
#    image_readingModes           categories  ... list_price  \
# 0               False                India  ...        0.0
# 1                True            Education  ...      276.0
# 2                True  Juvenile Nonfiction  ...       80.0
# 3               False                       ...        0.0
# 4                True       Social Science  ...      584.1
# 5                True       Social Science  ...      519.2
# 6               False    Political Science  ...        0.0
# 7                True            Education  ...      466.1
# 8               False        United States  ...        0.0
# 9                True                       ...        0.0
#
#   currencyCode_listPrice  retail_price currencyCode_retailPrice  \
# 0                                 0.00
# 1                    INR        193.20                      INR
# 2                    INR         80.00                      INR
# 3                                 0.00
# 4                    INR        292.05                      INR
# 5                    INR        259.60                      INR
# 6                                 0.00
# 7                    INR        326.27                      INR
# 8                                 0.00
# 9                                 0.00
#
#    average_rating ratings_count  country  page_count language  is_ebook
# 0             0.0             0                    0       en     False
# 1             0.0             0                  176       en      True
# 2             0.0             0                   33       en      True
# 3             0.0             0                  124       en     False
# 4             5.0             1                  199       en      True
# 5             0.0             0                  144       en      True
# 6             0.0             0                  228       en     False
# 7             0.0             0                  217       en      True
# 8             0.0             0                  468       en     False
# 9             0.0             0                  164       en     False
#
# [10 rows x 22 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
books_df
# Out:
#         book_id search_key                                         book_title  \
# 0  CxJn0AEACAAJ     civics                      Social and Political Life-III
# 1  EXUWEAAAQBAJ     civics               Excursions 8 History/Civics- (17-18)
# 2  MHM-EAAAQBAJ     civics  Solutions to FOCUS ON History and CIVICS for C...
# 3  oJyPxgEACAAJ     civics                                             French
# 4  JwFjDwAAQBAJ     civics           New Transitions  History and Civics  6
# 5  X9ExEAAAQBAJ     civics                      My Book of History & Civics 8
# 6  mQwOx8KWzk8C     civics                                    Civic Education
# 7  wyoxDAAAQBAJ     civics               Transitions  History and Civics  8
# 8  lS4XAAAAIAAJ     civics                                     The New Civics
# 9  J1oXEQAAQBAJ     civics  An Introduction to Civics and Citizenship Educ...
#
#                                        book_subtitle  \
# 0                           Textbook for Class VIII.
# 1                                                 NA
# 2                                                 NA
# 3  Teachers and Students Wide Ruled Line Journal ...
# 4                                                 NA
# 5                                                 NA
# 6                          What Makes Students Learn
# 7                                                 NA
# 8                   A Textbook for Secondary Schools
# 9            A Machine-Generated Literature Overview
#
#                                         book_authors  \
# 0
# 1                                          No Author
# 2  I. L. Wanchoo, Arun Kumar, Goyal Brothers Prak...
# 3                              Olivia Julius Dunggat
# 4                     Anuradha Sud, Shiladitya Ghosh
# 5                                     Manju Bhashini
# 6                        Richard G. Niemi, Jane Junn
# 7                                   Shiladitya Ghosh
# 8                                Roscoe Lewis Ashley
# 9                                      Keith Heggart
#
#              book_publisher industryIdentifiers  text_readingModes  \
# 0                                         OTHER              False
# 1             HarperCollins             ISBN_13              False
# 2  Goyal Brothers Prakashan                                  False
# 3   Independently Published             ISBN_10              False
# 4    Vikas Publishing House             ISBN_13              False
# 5   Saraswati House Pvt Ltd             ISBN_13              False
# 6     Yale University Press             ISBN_10               True
# 7    Vikas Publishing House             ISBN_13              False
# 8                                         OTHER              False
# 9           Springer Nature             ISBN_13               True
#
#    image_readingModes           categories published_year   saleability  \
# 0               False                India           2012  NOT_FOR_SALE
# 1                True            Education           2020      FOR_SALE
# 2                True  Juvenile Nonfiction           2021      FOR_SALE
# 3               False                                2019  NOT_FOR_SALE
# 4                True       Social Science                     FOR_SALE
# 5                True       Social Science                     FOR_SALE
# 6               False    Political Science           2005  NOT_FOR_SALE
# 7                True            Education                     FOR_SALE
# 8               False        United States           1921  NOT_FOR_SALE
# 9                True                                      NOT_FOR_SALE
#
#    list_price currencyCode_listPrice  retail_price currencyCode_retailPrice  \
# 0         0.0                                 0.00
# 1       276.0                    INR        193.20                      INR
# 2        80.0                    INR         80.00                      INR
# 3         0.0                                 0.00
# 4       584.1                    INR        292.05                      INR
# 5       519.2                    INR        259.60                      INR
# 6         0.0                                 0.00
# 7       466.1                    INR        326.27                      INR
# 8         0.0                                 0.00
# 9         0.0                                 0.00
#
#    average_rating  ratings_count country  page_count language  is_ebook
# 0             0.0              0                   0       en     False
# 1             0.0              0                 176       en      True
# 2             0.0              0                  33       en      True
# 3             0.0              0                 124       en     False
# 4             5.0              1                 199       en      True
# 5             0.0              0                 144       en      True
# 6             0.0              0                 228       en     False
# 7             0.0              0                 217       en      True
# 8             0.0              0                 468       en     False
# 9             0.0              0                 164       en     False

# %%
books_df.loc[2][:]
# Out:
# book_id                                                          MHM-EAAAQBAJ
# search_key                                                             civics
# book_title                  Solutions to FOCUS ON History and CIVICS for C...
# book_subtitle                                                              NA
# book_authors                I. L. Wanchoo, Arun Kumar, Goyal Brothers Prak...
# book_publisher                                       Goyal Brothers Prakashan
# industryIdentifiers
# text_readingModes                                                       False
# image_readingModes                                                       True
# categories                                                Juvenile Nonfiction
# published_year                                                           2021
# saleability                                                          FOR_SALE
# list_price                                                               80.0
# currencyCode_listPrice                                                    INR
# retail_price                                                             80.0
# currencyCode_retailPrice                                                  INR
# average_rating                                                            0.0
# ratings_count                                                               0
# country
# page_count                                                                 33
# language                                                                   en
# is_ebook                                                                 True
# Name: 2, dtype: object

# %%
books_df.fillna('', inplace=True)

# %%
books_df.shape
# Out:
# (10, 22)

# %%
books_df.dtypes
# Out:
# book_id                             object
# search_key                          object
# book_title                          object
# book_subtitle                       object
# book_authors                        object
# book_publisher                      object
# industryIdentifiers                 object
# text_readingModes                     bool
# image_readingModes                    bool
# categories                          object
# published_year              datetime64[ns]
# saleability                         object
# list_price                         float64
# currencyCode_listPrice              object
# retail_price                       float64
# currencyCode_retailPrice            object
# average_rating                     float64
# ratings_count                        int64
# country                             object
# page_count                           int64
# language                            object
# is_ebook                              bool
# dtype: object

# %%
books_df['published_year'] = pd.to_datetime(books_df['published_year'])

# %%
import pymysql

# %%
books_df['published_year']=pd.to_datetime(books_df['published_year'],errors='coerce')

# %%
import pymysql

# %%
db_config ={
    'host':'localhost',
     'user':'root',
      'password':'kasthuri67' 
}

conn = pymysql.connect(**db_config)
cursor=conn.cursor()
cursor.execute("create database if not exists bookspace")
cursor.execute("use bookspace")
# Out:
# 0

# %%
create_table_query = """
CREATE TABLE IF NOT EXISTS books_tables (
    book_id VARCHAR(255), 
    search_key VARCHAR(255),         
    book_title VARCHAR(255),         
    book_subtitle TEXT,              
    book_authors TEXT,
    book_publisher TEXT,                
    industryIdentifiers TEXT,        
    text_readingModes BOOLEAN,       
    image_readingModes BOOLEAN,
    categories TEXT,
    published_year DATE,
    saleability VARCHAR(50),
    list_price DECIMAL(10, 2), 
    currencyCode_listPrice VARCHAR(10), 
    retail_price DECIMAL(10, 2), 
    currencyCode_retailPrice VARCHAR(10),
    average_rating DECIMAL(3, 2) NULL,
    ratings_count INT,
    country VARCHAR(10),
    page_count INT,                   
    language VARCHAR(10),        
    is_ebook BOOLEAN    
)
"""
cursor.execute(create_table_query)
print("Table `books_tables` created or already exists.")
# Out:
# Table `books_tables` created or already exists.

# %%
insert_query = """
INSERT INTO books_tables (
    book_id, 
    search_key, 
    book_title, 
    book_subtitle, 
    book_authors, 
    book_publisher,     
    industryIdentifiers, 
    text_readingModes, 
    image_readingModes,     
    categories,
    published_year,          
    saleability,      
    list_price, 
    currencyCode_listPrice, 
    retail_price, 
    currencyCode_retailPrice,    
    average_rating,
    ratings_count,     
    country,
    page_count,
    language, 
    is_ebook
) 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
for index, row in books_df.iterrows():
    cursor.execute(insert_query, (row['book_id'], row['search_key'], row['book_title'], row['book_subtitle'], row['book_authors'], row['book_publisher'], row['industryIdentifiers'], row['text_readingModes'], row['image_readingModes'], row['categories'], row['published_year'], row['saleability'], row['list_price'], row['currencyCode_listPrice'], row['retail_price'], row['currencyCode_retailPrice'], row['average_rating'], row['ratings_count'], row['country'], row['page_count'], row['language'], row['is_ebook']))
    
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for index, row in books_df.iterrows():
#       2     cursor.execute(insert_query, (row['book_id'], row['search_key'], row['book_title'], row['book_subtitle'], row['book_authors'], row['book_publisher'], row['industryIdentifiers'], row['text_readingModes'], row['image_readingModes'], row['categories'], row['published_year'], row['saleability'], row['list_price'], row['currencyCode_listPrice'], row['retail_price'], row['currencyCode_retailPrice'], row['average_rating'], row['ratings_count'], row['country'], row['page_count'], row['language'], row['is_ebook']))
#       4 conn.commit()
#
# NameError: name 'books_df' is not defined

# %%
books_df=books_df.fillna(0)

# %%
if published_year == '':
    published_year = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 if published_year == '':
#       2     published_year = None
#
# NameError: name 'published_year' is not defined
